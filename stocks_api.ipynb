# %%
### Let's start by gathering stock prices for Tesla, Bitcoin, and gold using APIs in Python.
# We'll use the Alpha Vantage API for this purpose. 
# Alpha Vantage provides a free API that supports stocks, cryptocurrencies, and commodities.

# %%
# Get an API Key from Alpha Vantage:

# %%
import requests
import pandas as pd 
import time

# Alpha Vantage API key

api_key = 'N5VKMI34VQHKOMU7'

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=N5VKMI34VQHKOMU7'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2024-05-21', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2024-05-21': {'1. open': '169.9400', '2. high': '174.9700', '3. low': '169.9400', '4. close': '173.4700', '5. volume': '6459800'}, '2024-05-20': {'1. open': '169.0000', '2. high': '170.1600', '3. low': '168.3800', '4. close': '169.9200', '5. volume': '2726261'}, '2024-05-17': {'1. open': '168.9700', '2. high': '169.1100', '3. low': '167.3300', '4. close': '169.0300', '5. volume': '2956387'}, '2024-05-16': {'1. open': '168.2600', '2. high': '169.6300', '3. low': '167.7900', '4. close': '168.9700', '5. volume': '3492267'}, '2024-05-15': {'1. open': '167.9400', '2. high': '168.3500', '3. low': '167.3400', '4. close': '168.2600', '5. volume': '4468823'}, '2024-05-14': {'1. open': '167.8600', '2. high': '168.1300', '3. low': '166.4800', '4. close': '167.3600', '5. volume': '2600967'}, '2024-05-13': {'1. open': '167.5000', '2. high': '168.0600', '3. low': '166.7600', '4. close': '167.5600', '5. volume': '2414859'}, '2024-05-10': {'1. open': '167.1300', '2. high': '168.0700', '3. low': '166.3200', '4. close': '167.1500', '5. volume': '2255370'}, '2024-05-09': {'1. open': '167.5000', '2. high': '167.5500', '3. low': '165.8800', '4. close': '166.2700', '5. volume': '4266616'}, '2024-05-08': {'1. open': '168.0100', '2. high': '170.2600', '3. low': '167.9000', '4. close': '169.9000', '5. volume': '3522011'}, '2024-05-07': {'1. open': '169.0000', '2. high': '169.2900', '3. low': '167.9400', '4. close': '168.3800', '5. volume': '3155260'}, '2024-05-06': {'1. open': '166.5000', '2. high': '168.6700', '3. low': '166.3800', '4. close': '168.6100', '5. volume': '4222266'}, '2024-05-03': {'1. open': '165.0000', '2. high': '166.6100', '3. low': '164.9200', '4. close': '165.7100', '5. volume': '3400405'}, '2024-05-02': {'1. open': '164.3500', '2. high': '164.8800', '3. low': '162.6200', '4. close': '164.6900', '5. volume': '3829853'}, '2024-05-01': {'1. open': '165.6900', '2. high': '166.2700', '3. low': '164.3000', '4. close': '164.4300', '5. volume': '4030960'}, '2024-04-30': {'1. open': '166.4900', '2. high': '166.7600', '3. low': '165.2605', '4. close': '166.2000', '5. volume': '6011634'}, '2024-04-29': {'1. open': '167.4000', '2. high': '168.2200', '3. low': '166.2250', '4. close': '167.4300', '5. volume': '5263342'}, '2024-04-26': {'1. open': '167.5000', '2. high': '167.8700', '3. low': '165.7300', '4. close': '167.1300', '5. volume': '8983796'}, '2024-04-25': {'1. open': '168.2000', '2. high': '172.4500', '3. low': '165.6600', '4. close': '168.9100', '5. volume': '16702150'}, '2024-04-24': {'1. open': '183.1700', '2. high': '184.2900', '3. low': '181.4000', '4. close': '184.1000', '5. volume': '7616643'}, '2024-04-23': {'1. open': '182.7300', '2. high': '184.6800',
 'overall_sentiment_label': 'Somewhat-Bullish', 'ticker_sentiment': [{'ticker': 'AAPL', 'relevance_score': '0.123844', 'ticker_sentiment_score': '0.308269', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'BAC', 'relevance_score': '0.031079', 'ticker_sentiment_score': '0.207201', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'CVX', 'relevance_score': '0.093047', 'ticker_sentiment_score': '0.056216', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'PARA', 'relevance_score': '0.031079', 'ticker_sentiment_score': '0.010419', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'BRK-A', 'relevance_score': '0.154455', 'ticker_sentiment_score': '0.034223', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'ITOCF', 'relevance_score': '0.031079', 'ticker_sentiment_score': '0.0', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'OXY', 'relevance_score': '0.06211', 'ticker_sentiment_score': '0.053143', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'LEN', 'relevance_score': '0.06211', 'ticker_sentiment_score': '0.104026', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'MA', 'relevance_score': '0.06211', 'ticker_sentiment_score': '0.182131', 'ticker_sentiment_label': 'Somewhat-Bullish'}, {'ticker': 'MARUF', 'relevance_score': '0.031079', 'ticker_sentiment_score': '0.0', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'MITSF', 'relevance_score': '0.031079', 'ticker_sentiment_score': '0.0', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'SSUMF', 'rel ...

# %%
# Function to fetch gold stock data
def fetch_gold_data(symbol):
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={api_key}'
    response = requests.get(url)
    data = response.json()
    if "Time Series (Daily)" in data:
        time_series = data['Time Series (Daily)']
        df = pd.DataFrame.from_dict(time_series, orient='index')
        df = df.astype(float)
        df.index = pd.to_datetime(df.index)
        return df
    else:
        print(f"Error fetching data for {symbol}: {data}")
        return pd.DataFrame()

# Fetch data for gold-related stocks
gold_etf = fetch_gold_data('GLD')  # SPDR Gold Shares ETF
gold_miners_etf = fetch_gold_data('GDX')  # VanEck Vectors Gold Miners ETF

# Print data
print("SPDR Gold Shares ETF (GLD) Data:")
print(gold_etf.head())

print("\nVanEck Vectors Gold Miners ETF (GDX) Data:")
print(gold_miners_etf.head())
# Out:
# SPDR Gold Shares ETF (GLD) Data:
#             1. open   2. high  3. low  4. close   5. volume
# 2024-05-21   224.77  225.2100  223.70    224.23   4002615.0
# 2024-05-20   223.79  225.6600  223.02    224.56   5990860.0
# 2024-05-17   222.18  223.8501  221.67    223.66  10481937.0
# 2024-05-16   220.14  220.5850  219.41    220.03   4301652.0
# 2024-05-15   219.06  221.1900  217.65    220.89   9297715.0
#
# VanEck Vectors Gold Miners ETF (GDX) Data:
#             1. open  2. high   3. low  4. close   5. volume
# 2024-05-21    37.02    37.22  36.7300     36.93  17236070.0
# 2024-05-20    36.95    37.47  36.5201     37.24  24774504.0
# 2024-05-17    36.21    36.89  36.0000     36.87  38752317.0
# 2024-05-16    35.67    35.89  35.3300     35.66  19420393.0
# 2024-05-15    35.80    36.11  35.0600     35.91  24490479.0

# %%
gold_etf.tail()
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# 2024-01-04   189.08   189.75  188.69    189.32  4416743.0
# 2024-01-03   188.77   189.86  188.16    189.13  8661568.0
# 2024-01-02   191.44   191.89  190.50    190.72  6025646.0
# 2023-12-29   190.99   191.64  190.74    191.17  4612349.0
# 2023-12-28   192.34   192.89  191.44    191.47  6171506.0

# %%
# Function to fetch gold price data
def fetch_gold_price():
    url = f'https://www.alphavantage.co/query?function=COMMODITY_EXCHANGE_RATE&from_symbol=XAU&to_symbol=USD&apikey={api_key}'
    response = requests.get(url)
    data = response.json()
    if "Realtime Currency Exchange Rate" in data:
        price = data["Realtime Currency Exchange Rate"]["5. Exchange Rate"]
        return float(price)
    else:
        print(f"Error fetching data: {data}")
        return None

# Fetch data
gold_price = fetch_gold_price()

# Print data
if gold_price:
    print(f"The current price of gold is ${gold_price} per ounce")
# Out:
# Error fetching data: {'Error Message': 'This API function (COMMODITY_EXCHANGE_RATE) does not exist.'}

# %%
# Function to fetch stock data
def fetch_stock_data(symbol):
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={api_key}'
    response = requests.get(url)
    data = response.json()
    if "Time Series (Daily)" in data:
        time_series = data['Time Series (Daily)']
        df = pd.DataFrame.from_dict(time_series, orient='index')
        df = df.astype(float)
        df.index = pd.to_datetime(df.index)
        df = df.sort_index()
        return df
    else:
        print(f"Error fetching data for {symbol}: {data}")
        return pd.DataFrame()

# Fetch data for Tesla (TSLA)
tesla_data = fetch_stock_data('TSLA')

# Print data
print("Tesla Stock Data:")
print(tesla_data.head())
# Out:
# Tesla Stock Data:
#             1. open  2. high  3. low  4. close    5. volume
# 2023-12-28   263.66   265.13  252.71    253.18  113619943.0
# 2023-12-29   255.10   255.19  247.43    248.48  100891578.0
# 2024-01-02   250.08   251.25  244.41    248.42  104654163.0
# 2024-01-03   244.98   245.68  236.32    238.45  121082599.0
# 2024-01-04   239.25   242.70  237.73    237.93  102629283.0

# %%
tesla_data.tail()
# Out:
#             1. open  2. high  3. low  4. close    5. volume
# 2024-05-15   179.90  180.000  173.11    173.99   79662993.0
# 2024-05-16   174.10  175.790  171.43    174.84   59812220.0
# 2024-05-17   173.55  179.630  172.75    177.46   77445845.0
# 2024-05-20   177.56  177.754  173.52    174.95   61727425.0
# 2024-05-21   175.51  186.875  174.71    186.60  115266512.0

# %%
# Function to fetch Bitcoin data
def fetch_crypto_data(symbol, market):
    url = f'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol={symbol}&market={market}&apikey={api_key}'
    response = requests.get(url)
    data = response.json()
    if "Time Series (Digital Currency Daily)" in data:
        time_series = data['Time Series (Digital Currency Daily)']
        df = pd.DataFrame.from_dict(time_series, orient='index')
        df = df.astype(float)
        df.index = pd.to_datetime(df.index)
        df = df.sort_index()
        return df
    else:
        print(f"Error fetching data for {symbol}: {data}")
        return pd.DataFrame()

# Fetch data for Bitcoin (BTC) in USD
bitcoin_data = fetch_crypto_data('BTC', 'USD')

# Print data
print("Bitcoin Data (USD):")
print(bitcoin_data.head())
# Out:
# Bitcoin Data (USD):
#              1. open   2. high    3. low  4. close     5. volume
# 2023-07-28  29214.93  29532.45  29115.32  29316.15   7104.736395
# 2023-07-29  29316.05  29411.09  29253.44  29355.71   2893.052988
# 2023-07-30  29356.65  29450.00  29033.00  29281.39   4387.572566
# 2023-07-31  29280.41  29526.99  29102.65  29230.67   8793.063285
# 2023-08-01  29230.61  29726.73  28477.00  29697.27  17752.839341

# %%
bitcoin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 300 entries, 2023-07-28 to 2024-05-22
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   1. open    300 non-null    float64
#  1   2. high    300 non-null    float64
#  2   3. low     300 non-null    float64
#  3   4. close   300 non-null    float64
#  4   5. volume  300 non-null    float64
# dtypes: float64(5)
# memory usage: 14.1 KB
